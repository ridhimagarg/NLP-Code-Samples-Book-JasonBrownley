# %% [markdown]
# ## Data Preparation

# %%
from nltk.corpus import stopwords
import string
import re
from collections import Counter
import os

# %%
print(re.escape(string.punctuation))
# Out:
# \!\"\#\$\%\&\'\(\)\*\+\,\-\.\/\:\;\<\=\>\?\@\[\\\]\^_\`\{\|\}\~

# %%
def load_doc(filename):
    file = open(filename, 'r')
    text = file.read()
    file.close()
    
    return text

# %%
def clean_doc(doc):
    
    tokens = doc.split()
    
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    
    tokens = [re_punc.sub('',w) for w in tokens]

    tokens = [word for word in tokens if word.isalpha()]
    
    stop_words = set(stopwords.words('english'))
    
    tokens = [word for word in tokens if not word in stop_words]
    
    tokens = [word for word in tokens if len(word)>1]
    
    return tokens

# %%
filename = '../../data/input/txt_sentoken/neg/cv000_29416.txt'

# %%
text = load_doc(filename)
tokens = clean_doc(text)
print(tokens)
# Out:
# ['plot', 'two', 'teen', 'couples', 'go', 'church', 'party', 'drink', 'drive', 'get', 'accident', 'one', 'guys', 'dies', 'girlfriend', 'continues', 'see', 'life', 'nightmares', 'whats', 'deal', 'watch', 'movie', 'sorta', 'find', 'critique', 'mindfuck', 'movie', 'teen', 'generation', 'touches', 'cool', 'idea', 'presents', 'bad', 'package', 'makes', 'review', 'even', 'harder', 'one', 'write', 'since', 'generally', 'applaud', 'films', 'attempt', 'break', 'mold', 'mess', 'head', 'lost', 'highway', 'memento', 'good', 'bad', 'ways', 'making', 'types', 'films', 'folks', 'didnt', 'snag', 'one', 'correctly', 'seem', 'taken', 'pretty', 'neat', 'concept', 'executed', 'terribly', 'problems', 'movie', 'well', 'main', 'problem', 'simply', 'jumbled', 'starts', 'normal', 'downshifts', 'fantasy', 'world', 'audience', 'member', 'idea', 'whats', 'going', 'dreams', 'characters', 'coming', 'back', 'dead', 'others', 'look', 'like', 'dead', 'strange', 'apparitions', 'disappearances', 'looooot', 'chase', 'scenes', 'tons', 'weird', 'things', 'happen', 'simply', 'explained', 'personally', 'dont', 'mind', 'trying', 'unravel', 'film', 'every', 'give', 'clue', 'get', 'kind', 'fed', 'films', 'biggest', 'problem', 'obviously', 'got', 'big', 'secret', 'hide', 'seems', 'want', 'hide', 'completely', 'final', 'five', 'minutes', 'make', 'things', 'entertaining', 'thrilling', 'even', 'engaging', 'meantime', 'really', 'sad', 'part', 'arrow', 'dig', 'flicks', 'like', 'actually', 'figured', 'halfway', 'point', 'strangeness', 'start', 'make', 'little', 'bit', 'sense', 'still', 'didnt', 'make', 'film', 'entertaining', 'guess', 'bottom', 'line', 'movies', 'like', 'always', 'make', 'sure', 'audience', 'even', 'given', 'secret', 'password', 'enter', 'world', 'understanding', 'mean', 'showing', 'melissa', 'sagemiller', 'running', 'away', 'visions', 'minutes', 'throughout', 'movie', 'plain', 'lazy', 'okay', 'get', 'people', 'chasing', 'dont', 'know', 'really', 'need', 'see', 'giving', 'us', 'different', 'scenes', 'offering', 'insight', 'strangeness', 'going', 'movie', 'apparently', 'studio', 'took', 'film', 'away', 'director', 'chopped', 'shows', 'mightve', 'pretty', 'decent', 'teen', 'mindfuck', 'movie', 'somewhere', 'guess', 'suits', 'decided', 'turning', 'music', 'video', 'little', 'edge', 'would', 'make', 'sense', 'actors', 'pretty', 'good', 'part', 'although', 'wes', 'bentley', 'seemed', 'playing', 'exact', 'character', 'american', 'beauty', 'new', 'neighborhood', 'biggest', 'kudos', 'go', 'sagemiller', 'holds', 'throughout', 'entire', 'film', 'actually', 'feeling', 'characters', 'unraveling', 'overall', 'film', 'doesnt', 'stick', 'doesnt', 'entertain', 'confusing', 'rarely', 'excites', 'feels', 'pretty', 'redundant', 'runtime', 'despite', 'pretty', 'cool', 'ending', 'explanation', 'craziness', 'came', 'oh', 'way', 'horror', 'teen', 'slasher', 'flick', 'packaged', 'look', 'way', 'someone', 'apparently', 'assuming', 'genre', 'still', 'hot', 'kids', 'also', 'wrapped', 'production', 'two', 'years', 'ago', 'sitting', 'shelves', 'ever', 'since', 'whatever', 'skip', 'wheres', 'joblo', 'coming', 'nightmare', 'elm', 'street', 'blair', 'witch', 'crow', 'crow', 'salvation', 'lost', 'highway', 'memento', 'others', 'stir', 'echoes']

# %%
def add_doc_to_vocab(filename, vocab):
    doc = load_doc(filename)
    
    tokens = clean_doc(doc)
    
    vocab.update(tokens)

# %%
def process_docs(directory, vocab):
    
    for filename in os.listdir(directory):
        #print(filename)
        
        if filename.startswith('cv9'):
            #print(filename)
            continue
            
        path = directory+'/'+filename
        #print(path)

        add_doc_to_vocab(path, vocab)

# %%
vocab = Counter()

process_docs('../../data/input/txt_sentoken/neg', vocab)
process_docs('../../data/input/txt_sentoken/pos', vocab)

print(len(vocab))

print(vocab.most_common(50))
# Out:
# 44276
# [('film', 7983), ('one', 4946), ('movie', 4826), ('like', 3201), ('even', 2262), ('good', 2080), ('time', 2041), ('story', 1907), ('films', 1873), ('would', 1844), ('much', 1824), ('also', 1757), ('characters', 1735), ('get', 1724), ('character', 1703), ('two', 1643), ('first', 1588), ('see', 1557), ('way', 1515), ('well', 1511), ('make', 1418), ('really', 1407), ('little', 1351), ('life', 1334), ('plot', 1288), ('people', 1269), ('bad', 1248), ('could', 1248), ('scene', 1241), ('movies', 1238), ('never', 1201), ('best', 1179), ('new', 1140), ('scenes', 1135), ('man', 1131), ('many', 1130), ('doesnt', 1118), ('know', 1092), ('dont', 1086), ('hes', 1024), ('great', 1014), ('another', 992), ('action', 985), ('love', 977), ('us', 967), ('go', 952), ('director', 948), ('end', 946), ('something', 945), ('still', 936)]

# %%
min_occurence = 2

tokens = [k for k,c in vocab.items() if c>min_occurence]

# %%
len(tokens)
print(tokens)
# Out:
# ['plot', 'two', 'teen', 'couples', 'go', 'church', 'party', 'drink', 'drive', 'get', 'accident', 'one', 'guys', 'dies', 'girlfriend', 'continues', 'see', 'life', 'nightmares', 'whats', 'deal', 'watch', 'movie', 'sorta', 'find', 'critique', 'mindfuck', 'generation', 'touches', 'cool', 'idea', 'presents', 'bad', 'package', 'makes', 'review', 'even', 'harder', 'write', 'since', 'generally', 'applaud', 'films', 'attempt', 'break', 'mold', 'mess', 'head', 'lost', 'highway', 'memento', 'good', 'ways', 'making', 'types', 'folks', 'didnt', 'correctly', 'seem', 'taken', 'pretty', 'neat', 'concept', 'executed', 'terribly', 'problems', 'well', 'main', 'problem', 'simply', 'jumbled', 'starts', 'normal', 'fantasy', 'world', 'audience', 'member', 'going', 'dreams', 'characters', 'coming', 'back', 'dead', 'others', 'look', 'like', 'strange', 'apparitions', 'disappearances', 'chase', 'scenes', 'tons', 'weird', 'things', 'happen', 'explained', 'personally', 'dont', 'mind', 'trying', 'unravel', 'film', 'every', 'give', 'clue', 'kind', 'fed', 'biggest', 'obviously', 'got', 'big', 'secret', 'hide', 'seems', 'want', 'completely', 'final', 'five', 'minutes', 'make', 'entertaining', 'thrilling', 'engaging', 'meantime', 'really', 'sad', 'part', 'arrow', 'dig', 'flicks', 'actually', 'figured', 'halfway', 'point', 'strangeness', 'start', 'little', 'bit', 'sense', 'still', 'guess', 'bottom', 'line', 'movies', 'always', 'sure', 'given', 'enter', 'understanding', 'mean', 'showing', 'melissa', 'sagemiller', 'running', 'away', 'visions', 'throughout', 'plain', 'lazy', 'okay', 'people', 'chasing', 'know', 'need', 'giving', 'us', 'different', 'offering', 'insight', 'apparently', 'studio', 'took', 'director', 'chopped', 'shows', 'mightve', 'decent', 'somewhere', 'suits', 'decided', 'turning', 'music', 'video', 'edge', 'would', 'actors', 'although', 'wes', 'bentley', 'seemed', 'playing', 'exact', 'character', 'american', 'beauty', 'new', 'neighborhood', 'kudos', 'holds', 'entire', 'feeling', 'overall', 'doesnt', 'stick', 'entertain', 'confusing', 'rarely', 'feels', 'redundant', 'runtime', 'despite', 'ending', 'explanation', 'craziness', 'came', 'oh', 'way', 'horror', 'slasher', 'flick', 'packaged', 'someone', 'assuming', 'genre', 'hot', 'kids', 'also', 'wrapped', 'production', 'years', 'ago', 'sitting', 'shelves', 'ever', 'whatever', 'skip', 'wheres', 'joblo', 'nightmare', 'elm', 'street', 'blair', 'witch', 'crow', 'salvation', 'stir', 'echoes', 'happy', 'bastards', 'quick', 'damn', 'bug', 'starring', 'jamie', 'lee', 'curtis', 'another', 'baldwin', 'brother', 'william', 'time', 'story', 'regarding', 'crew', 'comes', 'across', 'deserted', 'russian', 'tech', 'ship', 'kick', 'power', 'within', 'gore', 'bringing', 'action', 'sequences', 'virus', 'empty', 'flash', 'substance', 'middle', 'nowhere', 'origin', 'pink', 'flashy', 'thing', 'hit', 'mir', 'course', 'donald', 'sutherland', 'stumbling', 'around', 'hey', 'lets', 'robots', 'acting', 'average', 'likes', 'youre', 'likely', 'work', 'halloween', 'wasted', 'hes', 'real', 'star', 'stan', 'robot', 'design', 'cgi', 'occasional', 'shot', 'picking', 'someones', 'brain', 'body', 'parts', 'turn', 'heres', 'otherwise', 'much', 'sunken', 'jaded', 'viewer', 'thankful', 'invention', 'based', 'late', 'television', 'show', 'name', 'mod', 'squad', 'tells', 'tale', 'three', 'reformed', 'criminals', 'employ', 'police', 'undercover', 'however', 'wrong', 'evidence', 'gets', 'stolen', 'immediately', 'suspicion', 'ads', 'cuts', 'claire', 'danes', 'nice', 'hair', 'cute', 'outfits', 'car', 'chases', 'stuff', 'blowing', 'sounds', 'first', 'fifteen', 'quickly', 'becomes', 'apparent', 'certainly', 'slick', 'looking', 'complete', 'costumes', 'isnt', 'enough', 'best', 'described', 'cross', 'cop', 'stretched', 'span', 'hour', 'half', 'single', 'clich', 'matter', 'elements', 'recycled', 'everything', 'weve', 'already', 'seen', 'nothing', 'spectacular', 'sometimes', 'bordering', 'wooden', 'omar', 'epps', 'deliver', 'lines', 'bored', 'transfers', ...

# %%
def save_list(lines, filename):
    
    data = '\n'.join(lines)
    
    file = open(filename, 'w')
    
    file.write(data)
    
    file.close()

# %%
save_list(tokens, 'vocab.txt')

# %% [markdown]
# ## Train CNN with Embedding Layer

# %% [markdown]
# ### Preparing data for putting into Keras Model

# %%
def load_doc(filename):
    
    file = open(filename, 'r')
    
    text = file.read()
    
    file.close()
    
    return text

# %%
vocab = load_doc('vocab.txt')
vocab = set(vocab.split())

# %%
vocab
# Out:
# {'vu',
#  'amalgamation',
#  'utilized',
#  'sang',
#  'allout',
#  'janssen',
#  'whiplash',
#  'civil',
#  'remorse',
#  'wrongdoing',
#  'snobs',
#  'silent',
#  'dudes',
#  'penance',
#  'dozen',
#  'unflattering',
#  'endangers',
#  'cuesta',
#  'cabin',
#  'bud',
#  'quirky',
#  'virgils',
#  'level',
#  'regain',
#  'plummer',
#  'thumb',
#  'bummer',
#  'imparted',
#  'forefront',
#  'wellrounded',
#  'yawn',
#  'serves',
#  'sylvia',
#  'hall',
#  'punishment',
#  'intervals',
#  'kitty',
#  'miserable',
#  'smash',
#  'lift',
#  'mingna',
#  'forman',
#  'vanish',
#  'accuses',
#  'education',
#  'immoral',
#  'alicia',
#  'carmen',
#  'darn',
#  'poise',
#  'stewardess',
#  'gwen',
#  'hooks',
#  'unapologetically',
#  'slices',
#  'intolerable',
#  'tee',
#  'mob',
#  'slaps',
#  'commitment',
#  'mens',
#  'mirren',
#  'devises',
#  'manifestations',
#  'persecution',
#  'tickets',
#  'violet',
#  'election',
#  'ricardo',
#  'haunted',
#  'improved',
#  'claw',
#  'smugly',
#  'hamunaptra',
#  'smalltime',
#  'compensate',
#  'mall',
#  'verdict',
#  'semler',
#  'flawlessly',
#  'paragraphs',
#  'horses',
#  'brighter',
#  'proficient',
#  'idealized',
#  'initiates',
#  'maury',
#  'sweetheart',
#  'carrying',
#  'talkative',
#  'presents',
#  'moran',
#  'selfloathing',
#  'mommas',
#  'cheerfully',
#  'tones',
#  'caan',
#  'reduce',
#  'shrugs',
#  'traumatised',
#  'thou',
#  'webbers',
#  'aimee',
#  'dreams',
#  'earnestness',
#  'austrian',
#  'groove',
#  'ways',
#  'sheree',
#  'underwear',
#  'hendrix',
#  'examine',
#  'sams',
#  'quaint',
#  'expert',
#  'predominant',
#  'aw',
#  'vinyl',
#  'based',
#  'competitor',
#  'patchwork',
#  'constable',
#  'dracula',
#  'reliving',
#  'morse',
#  'evidence',
#  'promise',
#  'translated',
#  'counsel',
#  'busboy',
#  'enliven',
#  'lowly',
#  'titanics',
#  'dreamy',
#  'juries',
#  'druggie',
#  'output',
#  'thousands',
#  'repressed',
#  'headacheinducing',
#  'blows',
#  'dominique',
#  'tank',
#  'villains',
#  'josh',
#  'threats',
#  'coincidences',
#  'theron',
#  'grangers',
#  'truths',
#  'bedside',
#  'kyle',
#  'wave',
#  'underestimate',
#  'priest',
#  'bald',
#  'vr',
#  'viciously',
#  'rightly',
#  'gangland',
#  'climbing',
#  'resolutely',
#  'please',
#  'dramatically',
#  'collapsing',
#  'breathtakingly',
#  'oppressive',
#  'generic',
#  'quart',
#  'exotic',
#  'mulholland',
#  'urgency',
#  'rapidly',
#  'tool',
#  'sidekicks',
#  'turpin',
#  'alyssa',
#  'chairs',
#  'newsman',
#  'distracted',
#  'zoologist',
#  'pimp',
#  'quotient',
#  'sheltons',
#  'whilst',
#  'lookalikes',
#  'bits',
#  'see',
#  'happygolucky',
#  'proposal',
#  'farley',
#  'organisms',
#  'depth',
#  'cautionary',
#  'longstanding',
#  'unity',
#  'huddle',
#  'simpleminded',
#  'nolte',
#  'polishwedding',
#  'andre',
#  'moxon',
#  'way',
#  'heaps',
#  'onward',
#  'boy',
#  'clair',
#  'gibson',
#  'bullshit',
#  'gordy',
#  'distinctive',
#  'survives',
#  'hovering',
#  'seduce',
#  'makings',
#  'ready',
#  'credibility',
#  'first',
#  'heated',
#  'toxic',
#  'jon',
#  'flintstones',
#  'accidentally',
#  'niche',
#  'parttime',
#  'yelling',
#  'scares',
#  'navaz',
#  'shagwell',
#  'vow',
#  'radiates',
#  'countries',
#  'rebound',
#  'columbine',
#  'makers',
#  'catherine',
#  'writers',
#  'innocence',
#  'picks',
#  'gods',
#  'cottrell',
#  'stalking',
#  'bounds',
#  'english',
#  'jealousy',
#  'mickey',
#  'arroway',
#  'steals',
#  'seedy',
#  'hos',
#  'justifiable',
#  'gielgud',
#  'pipes',
#  'heroics',
#  'workers',
#  'christian',
#  'nowadays',
#  'mant',
#  'describe',
#  'naturally',
#  'afternoon',
#  'nation',
#  'portrait',
#  'conspiracies',
#  'eccentrics',
#  'kudrows',
#  'shuts',
#  'effectsladen',
#  'novelty',
#  'production',
#  'excellent',
#  'landmarks',
#  'stab',
#  'slop',
#  'felix',
#  'atop',
#  'clad',
#  'loveinterest',
#  'stripped',
#  'katana',
#  'claimed',
#  'psycho',
#  'wincott',
#  'rushed',
#  'coitus',
#  'invest',
#  'peaceful',
#  'upstairs',
#  'commits',
#  'liar',
#  'lived',
#  'chaser',
#  'distance',
#  'entity',
#  'lenny',
#  'marvel',
#  'piles',
#  'mime',
#  'amusement',
#  'hired',
#  'charmless',
#  'confusion',
#  'along',
#  'gut',
#  'laurie',
#  'claustrophobia',
#  'evenhanded',
#  'summoned',
#  'thirties',
#  'dermot',
#  'rowan',
#  'coating',
#  'subculture',
#  'cripple',
#  'studios',
#  'shadowed',
#  'lamely',
#  'odonnell',
#  'thematically',
#  'cowritten',
#  'brodericks',
#  'raul',
#  'pride',
#  'chicken',
#  'beatrice',
#  'fords',
#  'job',
#  'culinary',
#  'trifle',
#  'hops',
#  'lovejoy',
#  'handdrawn',
#  'reason',
#  'humankind',
#  'poitier',
#  'aversion',
#  'reverend',
#  'mortal',
#  'dreadful',
#  'berenger',
#  'honcho',
#  'matters',
#  'powers',
#  'gee',
#  'motorcycles',
#  'veers',
#  'pearce',
#  'ate',
#  'decked',
#  'herbie',
#  'meryl',
#  'acceptable',
#  'gripping',
#  'fran',
#  'engaged',
#  'scripts',
#  'government',
#  'hear',
#  'impromptu',
#  'mishmash',
#  'privy',
#  'vortex',
#  'chases',
#  'mainly',
#  'communication',
#  'leblanc',
#  'idiot',
#  'conversations',
#  'gerry',
#  'trusted',
#  'shop',
#  'trot',
#  'skinheads',
#  'loot',
#  'likelihood',
#  'thailand',
#  'cds',
#  'squandered',
#  'prepare',
#  'reshoots',
#  'prick',
#  'narrowly',
#  'considers',
#  'understand',
#  'honors',
#  'fragile',
#  'carvey',
#  'presences',
#  'century',
#  'slept',
#  'zahn',
#  'testing',
#  'niccols',
#  'annual',
#  'ketchum',
#  'corey',
#  'balance',
#  'hy',
#  'chocolat',
#  'unintentionally',
#  'slide',
#  'bogus',
#  'responsibility',
#  'donaldson',
#  'wellintentioned',
#  'cynicism',
#  'replied',
#  'solve',
#  'jekyll',
#  'maneating',
#  'solves',
#  'doses',
#  'devlin',
#  'strings',
#  'pudgy',
#  'chalk',
#  'vanishes',
#  'bullet',
#  'depicts',
#  'obscures',
#  'sissy',
#  'scientific',
#  'gadget',
#  'egyptian',
#  'aristocratic',
#  'voice',
#  'dwell',
#  'wilcock',
#  'politely',
#  'spews',
#  'alain',
#  'spawns',
#  'defeats',
#  'regulars',
#  'feldman',
#  'reflecting',
#  'inanity',
#  'humble',
#  'shooin',
#  'downside',
#  'fourteen',
#  'independent',
#  'jeanpierre',
#  'trimmed',
#  'undeveloped',
#  'accomplishments',
#  'locale',
#  'serviceable',
#  'blending',
#  'sunken',
#  'dusty',
#  'tutor',
#  'elements',
#  'jeanluc',
#  'errant',
#  'newspaper',
#  'villa',
#  'misery',
#  'inseparable',
#  'empathy',
#  'whiz',
#  'yup',
#  'ghosts',
#  'banks',
#  'confined',
#  'diverting',
#  'chock',
#  'look',
#  'snakes',
#  'dash',
#  'proceeds',
#  'criminal',
#  'fellow',
#  'uncontrollable',
#  'sadler',
#  'iguanas',
#  'huh',
#  'understood',
#  'nations',
#  'quiz',
#  'clever',
#  'counterfeit',
#  'slightly',
#  'added',
#  'millionaire',
#  'girlfriends',
#  'lump',
#  'whoever',
#  'environment',
#  'frustrated',
#  'obsolete',
#  'chubby',
#  'among',
#  'coined',
#  'capra',
#  'radical',
#  'acquaintances',
#  'tenderness',
#  'yahoo',
#  'fatherly',
#  'ordeal',
#  'writes',
#  'boldly',
#  'kristofferson',
#  'daddy',
#  'muppets',
#  'panache',
#  'reacts',
#  'myth',
#  'liaisons',
#  'fifteen',
#  'consistently',
#  'tend',
#  'jakob',
#  'airplane',
#  'diner',
#  'eye',
#  'obstetrician',
#  'endings',
#  'denver',
#  'anecdotes',
#  'truck',
#  'racism',
#  'universe',
#  'october',
#  'edgecomb',
#  'crystal',
#  'nab',
#  'elliott',
#  'knowingly',
#  'sasha',
#  'haircut',
#  'marginally',
#  'considering',
#  'text',
#  'remaking',
#  'hughes',
#  'thud',
#  'relates',
#  'downbeat',
#  'trek',
#  'kelsey',
#  'marie',
#  'mechanic',
#  'bai',
#  'loan',
#  'kidmans',
#  'bill',
#  'applegate',
#  'pathetic',
#  'review',
#  'caerthan',
#  'stairs',
#  'wig',
#  'holding',
#  'asinine',
#  'lyonne',
#  'basket',
#  'nielson',
#  'dumber',
#  'differentiate',
#  'recollection',
#  'rulers',
#  'emmerichs',
#  'sexy',
#  'arty',
#  'hess',
#  'bigtime',
#  'appreciated',
#  'accept',
#  'millie',
#  'performance',
#  'inspiration',
#  'gig',
#  'meets',
#  'tampopos',
#  'shifty',
#  'jamaica',
#  'lou',
#  'spanned',
#  'christ',
#  'blasting',
#  'melvin',
#  'broader',
#  'ehren',
#  'poking',
#  'yea',
#  'sprouse',
#  'prevalent',
#  'scientology',
#  'unspectacular',
#  'furniture',
#  'samurai',
#  'sheens',
#  'manipulated',
#  'machismo',
#  'pervasive',
#  'iq',
#  'cynics',
#  'coxs',
#  'statement',
#  'deteriorates',
#  'drawback',
#  'dressing',
#  'liberty',
#  'supplied',
#  'emerge',
#  'devoted',
#  'group',
#  'slater',
#  'kjv',
#  'gloss',
#  'till',
#  'teenage',
#  'preferring',
#  'clapton',
#  'loved',
#  'sheen',
#  'tens',
#  'calibre',
#  'krueger',
#  'flop',
#  'hunger',
#  'annoyed',
#  'violence',
#  'businesswoman',
#  'road',
#  'typically',
#  'sends',
#  'noir',
#  'dropping',
#  'chants',
#  'schindler',
#  'set',
#  'extraordinary',
#  'bucket',
#  'winding',
#  'uncles',
#  'manipulating',
#  'jocks',
#  'portray',
#  'enquirer',
#  'roundtree',
#  'coverup',
#  'mimmo',
#  'exhausted',
#  'shoved',
#  'cliched',
#  'medak',
#  'carlyle',
#  'shunned',
#  'capability',
#  'owe',
#  'mazzello',
#  'educate',
#  'gabe',
#  'supervisors',
#  'designed',
#  'umm',
#  'competitive',
#  'christina',
#  'conceal',
#  'stella',
#  'captivate',
#  'groetescheles',
#  'neatly',
#  'exhibit',
#  'incompetent',
#  'wraps',
#  'ant',
#  'brautigan',
#  'rickles',
#  'encounter',
#  'cardboard',
#  'bailed',
#  'reasons',
#  'fists',
#  'til',
#  'pitts',
#  'emptyheaded',
#  'delve',
#  'saws',
#  'strangle',
#  'bullseye',
#  'sleeps',
#  'electric',
#  'kahuna',
#  'balcony',
#  'herman',
#  'manned',
#  'accused',
#  'saving',
#  'spencers',
#  'marina',
#  'superheroes',
#  'romances',
#  'rep',
#  'privilege',
#  'remarkably',
#  'assigns',
#  'gills',
#  'cyril',
#  'hacked',
#  'michaels',
#  'uturn',
#  'unbridled',
#  'encouraged',
#  'extramarital',
#  'skinny',
#  'nicky',
#  'walked',
#  'biederman',
#  'westerns',
#  'waist',
#  'crosses',
#  'practiced',
#  'deadpan',
#  'aggressive',
#  'embrace',
#  'giallo',
#  'monday',
#  'privileged',
#  'obstacles',
#  'shackletons',
#  'catch',
#  'denied',
#  'cents',
#  'wilson',
#  'versa',
#  'overkill',
#  'mariah',
#  'introspective',
#  'terel',
#  'rolled',
#  'kungfu',
#  'robbies',
#  'swarms',
#  'arnie',
#  'mobile',
#  'dove',
#  'furst',
#  'sturdy',
#  'twentyone',
#  'repartee',
#  'randomly',
#  'ultimately',
#  'filmmakers',
#  'spine',
#  'tango',
#  'fenster',
#  'talents',
#  'shoveler',
#  'winkler',
#  'indie',
#  'stylist',
#  'gypsy',
#  'cameos',
#  'jolly',
#  'magnitude',
#  'local',
#  'gave',
#  'adaption',
#  'boxing',
#  'authored',
#  'enslaved',
#  'seagal',
#  'slower',
#  'swift',
#  'wherever',
#  'souza',
#  'wicked',
#  'four',
#  'troublesome',
#  'buster',
#  'white',
#  'ungar',
#  'littleknown',
#  'giles',
#  'postapocalyptic',
#  'attempting',
#  'empathize',
#  'previous',
#  'nobody',
#  'diedre',
#  'spends',
#  'morgue',
#  'object',
#  'items',
#  'comprised',
#  'mr',
#  'persuades',
#  'priests',
#  'stoop',
#  'starship',
#  'durden',
#  'horrors',
#  'stereotype',
#  'restricted',
#  'hinted',
#  'beats',
#  'musician',
#  'infests',
#  'colonial',
#  'errors',
#  'bellhop',
#  'highstakes',
#  'inferno',
#  'gals',
#  'basketball',
#  'pocket',
#  'riddick',
#  'disaster',
#  'custom',
#  'faceoff',
#  'winslow',
#  'mario',
#  'congenial',
#  'bulletproof',
#  'oaf',
#  'atmospheric',
#  'defect',
#  'exhusband',
#  'reappears',
#  'allied',
#  'greatlooking',
#  'phillips',
#  'meyers',
#  'aided',
#  'happened',
#  'sixteen',
#  'judges',
#  'batgirl',
#  'fuller',
#  'patients',
#  'spikes',
#  'tanaka',
#  'doyles',
#  'pad',
#  'misha',
#  'unworthy',
#  'potato',
#  'romance',
#  'screentime',
#  'stalked',
#  'glimpses',
#  'outrageously',
#  'congratulations',
#  'outdoors',
#  'dud',
#  'memphis',
#  'orser',
#  'telepathic',
#  'culture',
#  'bankrupt',
#  'shes',
#  'gotten',
#  'blatant',
#  'resonance',
#  'fuss',
#  'passion',
#  'primal',
#  'understanding',
#  'connecticut',
#  'eighty',
#  'vacant',
#  'irritation',
#  'buff',
#  'draw',
#  'raking',
#  'logical',
#  'irate',
#  'pillsbury',
#  'heterosexual',
#  'der',
#  'belgian',
#  'concede',
#  'demanded',
#  'annies',
#  'bothered',
#  'include',
#  'positioned',
#  'impossibly',
#  'highest',
#  'german',
#  'swashbuckling',
#  'budding',
#  'dichotomy',
#  'gum',
#  'buenos',
#  'argued',
#  'capone',
#  'highly',
#  'joely',
#  'chapel',
#  'crumbs',
#  'misunderstanding',
#  'efforts',
#  'billed',
#  'disenfranchised',
#  'regime',
#  'kaye',
#  'showdown',
#  'feelings',
#  'translator',
#  'heil',
#  'joblo',
#  'bleak',
#  'models',
#  'nonexistant',
#  'pickles',
#  'cynthias',
#  'mathilda',
#  'yugoslavia',
#  'attentions',
#  'insular',
#  'comparison',
#  'befuddled',
#  'weaknesses',
#  'fiddling',
#  'catalog',
#  'obsesses',
#  'peace',
#  'becker',
#  'oppressed',
#  'silvers',
#  'outline',
#  'challenged',
#  'dizzying',
#  'technically',
#  'thy',
#  'confirmed',
#  'broadcast',
#  'dalmatians',
#  'sickly',
#  'nosferatu',
#  'throw',
#  'jolies',
#  'julianne',
#  'colourful',
#  'equation',
#  'percy',
#  'joker',
#  'dirty',
#  'nurse',
#  'celebration',
#  'zip',
#  'jason',
#  'wretched',
#  'lauded',
#  'surrounding',
#  'wickedly',
#  'fry',
#  'withdrawal',
#  'silently',
#  'membership',
#  'oneroom',
#  'fantasies',
#  'snap',
#  'policeman',
#  'riding',
#  'wonderful',
#  'deserted',
#  'whole',
#  'offers',
#  'sherri',
#  'peacemaker',
#  'pines',
#  'seventh',
#  'freddy',
#  'arresting',
#  'promoted',
#  'indifferent',
#  'suit',
#  'gazes',
#  'bulworth',
#  'wanna',
#  'snubbed',
#  'menacingly',
#  'melts',
#  'disastrous',
#  'treacherous',
#  'unrealistic',
#  'thespians',
#  'retreat',
#  'wouldve',
#  'joking',
#  'robbers',
#  'street',
#  'malone',
#  'pace',
#  'checking',
#  'bear',
#  'sludge',
#  'grating',
#  'tropics',
#  'johnston',
#  'film',
#  'definition',
#  'raps',
#  'playbook',
#  ...}

# %%
def clean_doc(doc):
    
    tokens = doc.split()
    
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    
    tokens = [re_punc.sub('',w) for w in tokens]
    
    tokens = [w for w in tokens if w in vocab]
    
    tokens = ' '.join(tokens)
    
    return tokens

# %%
def process_docs(directory, vocab, is_train):
    documents = list()
    
    for filename in os.listdir(directory): 
        
        if is_train and filename.startswith('cv9'):
            continue
        if not is_train and not filename.startswith('cv9'):
            continue
        
        path = directory+'/'+filename

        doc = load_doc(path)

        tokens = clean_doc(doc, vocab)

        documents.append(tokens)
    
    return documents

# %%
# load and clean a dataset
def load_clean_dataset(vocab, is_train):
    # load documents
    neg = process_docs('txt_sentoken/neg', vocab, is_train)
    pos = process_docs('txt_sentoken/pos', vocab, is_train)
    docs = neg + pos
    # prepare labels
    labels = array([0 for _ in range(len(neg))] + [1 for _ in range(len(pos))])
    return docs, labels

# %%
def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    
    return tokenizer

# %%
max_length = max([len(s.split()) for s in train_docs])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8007d75dc858> in <module>()
# ----> 1 max_length = max([len(s.split()) for s in train_docs])
#
# NameError: name 'train_docs' is not defined

# %%
def encode_docs(tokenizer, max_length, docs):
    
    encoded = tokenizer.texts_to_sequences(docs)
    
    padded = pad_sequences(encoded, maxlen= max_length, padding= 'post' )
    
    return padded

# %%
vocab = len(tokenizer.word_index) + 1
print(vocab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-aae7b6aae165> in <module>()
# ----> 1 vocab = len(tokenizer.word_index) + 1
#       2 print(vocab)
#
# NameError: name 'tokenizer' is not defined

# %%
def define_model(vocab_size, max_length):
    model = Sequential()
    model.add(Embedding(vocab_size, 100, input_length = max_length))
    model.add(Conv1D(filters= 32, kernel_size =8, activation = 'relu'))
    model.add(MaxPooling1D(pool_size =2))
    model.add(Flatten())
    model.add(Dense(10, activation = 'relu' ))
    model.add(Dense(1, activation = 'sigmoid'))
    
    model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    
    model.summary()
    plot_model(model, to_file = 'model.png', show_shapes = True)
    
    return model

# %%
import string
import re
import os
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils.vis_utils import plot_model

def load_doc(filename):
    file = open(filename, 'r')
    text = file.read()
    file.close()
    
    return text

def clean_doc(doc, vocab):
    
    tokens = doc.split()
    
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    
    tokens = [re_punc.sub('',w) for w in tokens]
    
    tokens = [w for w in tokens if w in vocab]
    
    tokens = ' '.join(tokens)
    
    return tokens

def process_docs(directory, vocab, is_train):
    documents = list()
    
    for filename in os.listdir(directory): 
        
        if is_train and filename.startswith('cv9'):
            continue
        if not is_train and not filename.startswith('cv9'):
            continue
        
        path = directory+'/'+filename

        doc = load_doc(path)

        tokens = clean_doc(doc, vocab)

        documents.append(tokens)
    
    return documents

# load and clean a dataset
def load_clean_dataset(vocab, is_train):
    # load documents
    neg = process_docs('../../data/input/txt_sentoken/neg', vocab, is_train)
    pos = process_docs('../../data/input/txt_sentoken/pos', vocab, is_train)
    docs = neg + pos
    # prepare labels
    labels = array([0 for _ in range(len(neg))] + [1 for _ in range(len(pos))])
    return docs, labels

def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    
    return tokenizer

def encode_docs(tokenizer, max_length, docs):
    
    encoded = tokenizer.texts_to_sequences(docs)
    
    padded = pad_sequences(encoded, maxlen= max_length, padding= 'post' )
    
    return padded

def define_model(vocab_size, max_length):
    model = Sequential()
    model.add(Embedding(vocab_size, 100, input_length = max_length))
    model.add(Conv1D(filters= 32, kernel_size =8, activation = 'relu'))
    model.add(MaxPooling1D(pool_size =2))
    model.add(Flatten())
    model.add(Dense(10, activation = 'relu' ))
    model.add(Dense(1, activation = 'sigmoid'))
    
    model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    
    model.summary()
    #plot_model(model, to_file = 'model.png', show_shapes = True)
    
    return model



vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = set(vocab.split())

train_docs, ytrain = load_clean_dataset(vocab, True)
tokenizer = create_tokenizer(train_docs)

print(tokenizer)

vocab_size = len(tokenizer.word_index) +1

print('Vocab size %d' % vocab_size)

max_length = max([len(s.split()) for s in train_docs])

print('Maximum length %d' % max_length)

Xtrain = encode_docs(tokenizer, max_length, train_docs)

print(Xtrain)

model = define_model(vocab_size, max_length)

model.fit(Xtrain, ytrain, epochs = 10, verbose =2)

model.save('model.h5')
# Out:
# <keras_preprocessing.text.Tokenizer object at 0x00000146EF782FD0>
# Vocab size 19605
# Maximum length 1282
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Epoch 1/10
#  - 8s - loss: 0.6891 - acc: 0.5389
# Epoch 2/10
#  - 8s - loss: 0.5645 - acc: 0.7194
# Epoch 3/10
#  - 8s - loss: 0.1155 - acc: 0.9628
# Epoch 4/10
#  - 8s - loss: 0.0089 - acc: 0.9989
# Epoch 5/10
#  - 9s - loss: 0.0037 - acc: 0.9994
# Epoch 6/10
#  - 9s - loss: 0.0026 - acc: 0.9994
# Epoch 7/10
#  - 9s - loss: 0.0020 - acc: 0.9994
# Epoch 8/10
#  - 10s - loss: 0.0016 - acc: 0.9994
# Epoch 9/10
#  - 10s - loss: 0.0012 - acc: 0.9994
# Epoch 10/10
#  - 10s - loss: 7.9814e-04 - acc: 0.9994

# %%
# !pip install pydot
# Out:
# Collecting pydot
#   Using cached https://files.pythonhosted.org/packages/33/d1/b1479a770f66d962f545c2101630ce1d5592d90cb4f083d38862e93d16d2/pydot-1.4.1-py2.py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\admin\anaconda3\lib\site-packages (from pydot) (2.2.0)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.1
# distributed 1.21.8 requires msgpack, which is not installed.
# tensorflow 1.10.0 has requirement numpy<=1.14.5,>=1.13.3, but you'll have numpy 1.16.3 which is incompatible.
# tensorflow 1.10.0 has requirement setuptools<=39.1.0, but you'll have setuptools 41.0.1 which is incompatible.
# ipython 6.4.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 1.0.14 which is incompatible.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ---------
# absl-py                            0.7.1
# alabaster                          0.7.10
# anaconda-client                    1.6.14
# anaconda-navigator                 1.8.7
# anaconda-project                   0.8.2
# aniso8601                          8.0.0
# APScheduler                        3.6.0
# asn1crypto                         0.24.0
# astor                              0.8.0
# astroid                            2.2.5
# astropy                            3.0.2
# attrs                              18.1.0
# Automat                            0.7.0
# awsebcli                           3.15.3
# Babel                              2.5.3
# backcall                           0.1.0
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.6.0
# bitarray                           0.8.1
# bkcharts                           0.2
# blaze                              0.11.3
# bleach                             2.1.3
# blis                               0.2.4
# bokeh                              0.12.16
# boto                               2.48.0
# boto3                              1.9.162
# botocore                           1.12.162
# Bottleneck                         1.2.1
# cement                             2.8.2
# certifi                            2018.4.16
# cffi                               1.11.5
# chardet                            3.0.4
# click                              6.7
# cloudpickle                        0.5.3
# clyent                             1.2.2
# colorama                           0.3.9
# colorclass                         2.2.0
# coloredlogs                        10.0
# colorhash                          1.0.2
# comtypes                           1.1.4
# conda                              4.6.14
# conda-build                        3.10.5
# conda-verify                       2.0.0
# ConfigArgParse                     0.13.0
# constantly                         15.1.0
# contextlib2                        0.5.5
# cryptography                       2.2.2
# cycler                             0.10.0
# cymem                              2.0.2
# Cython                             0.28.2
# cytoolz                            0.9.0.1
# dask                               0.17.5
# datashape                          0.5.4
# decorator                          4.3.0
# distributed                        1.21.8
# docopt                             0.6.2
# docutils                           0.14
# en-core-web-sm                     2.1.0
# entrypoints                        0.2.3
# et-xmlfile                         1.0.1
# fakeredis                          0.10.3
# fastcache                          1.0.2
# fbmessenger                        5.6.0
# filelock                           3.0.4
# Flask                              1.0.2
# Flask-Cors                         3.0.4
# Flask-JWT-Simple                   0.0.3
# flask-restplus                     0.13.0
# future                             0.16.0
# gast                               0.2.2
# gensim                             3.7.3
# gevent                             1.3.0
# glob2                              0.6
# graphviz                           0.9
# greenlet                           0.4.13
# grpcio                             1.21.1
# h5py                               2.7.1
# heapdict                           1.0.0
# html5lib                           1.0.1
# humanfriendly                      4.18
# hyperlink                          19.0.0
# idna                               2.7
# imageio                            2.3.0
# imagesize                          1.0.0
# incremental                        17.5.0
# ipykernel                          4.8.2
# ipython                            6.4.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.2.1
# isort                              4.3.21
# itsdangerous                       0.24
# jdcal                              1.4
# jedi                               0.12.0
# Jinja2                             2.10
# jmespath                           0.9.4
# jsonpickle                         0.9.6
# jsonschema                         2.6.0
# jupyter                            1.0.0
# jupyter-client                     5.2.3
# jupyter-console                    5.2.0
# jupyter-core                       4.4.0
# jupyterlab                         0.32.1
# jupyterlab-launcher                0.10.5
# Keras                              2.2.4
# Keras-Applications                 1.0.8
# Keras-Preprocessing                1.1.0
# kiwisolver                         1.0.1
# klein                              17.10.0
# lazy-object-proxy                  1.4.1
# llvmlite                           0.23.1
# locket                             0.2.0
# lxml                               4.2.1
# Markdown                           3.1.1
# MarkupSafe                         1.0
# matplotlib                         2.2.2
# mattermostwrapper                  2.1
# mccabe                             0.6.1
# menuinst                           1.4.14
# mistune                            0.8.3
# mkl-fft                            1.0.0
# mkl-random                         1.0.1
# mock                               3.0.5
# more-itertools                     4.1.0
# mpmath                             1.0.0
# msgpack-python                     0.5.6
# multipledispatch                   0.5.0
# murmurhash                         1.0.2
# navigator-updater                  0.2.1
# nbconvert                          5.3.1
# nbformat                           4.4.0
# networkx                           2.1
# nltk                               3.3
# nose                               1.3.7
# notebook                           5.5.0
# numba                              0.38.0
# numexpr                            2.6.5
# numpy                              1.16.3
# numpydoc                           0.8.0
# odo                                0.5.1
# olefile                            0.45.1
# openpyxl                           2.5.3
# packaging                          17.1
# pandas                             0.23.0
# pandocfilters                      1.4.2
# parso                              0.2.0
# partd                              0.3.8
# path.py                            11.0.1
# pathlib                            1.0.1
# pathlib2                           2.3.2
# pathspec                           0.5.9
# patsy                              0.5.0
# pep8                               1.7.1
# pickleshare                        0.7.4
# pika                               0.11.2
# Pillow                             5.1.0
# pip                                10.0.1
# pkginfo                            1.4.2
# plac                               0.9.6
# pluggy                             0.6.0
# ply                                3.11
# preshed                            2.0.1
# prompt-toolkit                     1.0.14
# protobuf                           3.8.0
# psutil                             5.4.5
# py                                 1.5.3
# pycodestyle                        2.4.0
# pycosat                            0.6.3
# pycparser                          2.18
# pycrypto                           2.6.1
# pycurl                             7.43.0.1
# pydot                              1.4.1
# pyflakes                           1.6.0
# Pygments                           2.2.0
# PyHamcrest                         1.9.0
# PyInquirer                         1.0.3
# PyJWT                              1.7.1
# pykwalify                          1.6.0
# pylint                             2.3.1
# pymongo                            3.8.0
# pyodbc                             4.0.23
# pyOpenSSL                          18.0.0
# pyparsing                          2.2.0
# pypiwin32                          223
# pyreadline                         2.1
# PySocks                            1.6.8
# pytest                             3.5.1
# pytest-arraydiff                   0.2
# pytest-astropy                     0.3.0
# pytest-doctestplus                 0.1.3
# pytest-openfiles                   0.3.0
# pytest-remotedata                  0.2.1
# python-crfsuite                    0.9.6
# python-dateutil                    2.7.3
# python-engineio                    3.8.0
# python-socketio                    2.1.2
# python-telegram-bot                10.1.0
# pytz                               2018.4
# PyWavelets                         0.5.2
# pywin32                            224
# pywinpty                           0.5.1
# PyYAML                             3.13
# pyzmq                              17.0.0
# QtAwesome                          0.4.4
# qtconsole                          4.3.1
# QtPy                               1.4.1
# rasa-core                          0.11.11
# rasa-core-sdk                      0.11.5
# rasa-nlu                           0.13.6
# redis                              2.10.6
# regex                              2019.6.5
# requests                           2.20.1
# rocketchat-API                     0.6.32
# rope                               0.10.7
# ruamel-yaml                        0.15.35
# ruamel.yaml                        0.15.97
# s3transfer                         0.2.1
# scikit-image                       0.13.1
# scikit-learn                       0.19.2
# scipy                              1.3.0
# seaborn                            0.8.1
# semantic-version                   2.5.0
# Send2Trash                         1.5.0
# setuptools                         41.0.1
# simplegeneric                      0.8.1
# simplejson                         3.16.0
# singledispatch                     3.4.0.3
# six                                1.11.0
# sklearn-crfsuite                   0.3.6
# slackclient                        1.3.2
# smart-open                         1.8.4
# snowballstemmer                    1.2.1
# sortedcollections                  0.6.1
# sortedcontainers                   1.5.10
# spacy                              2.1.4
# Sphinx                             1.7.4
# sphinxcontrib-websupport           1.0.1
# spyder                             3.2.8
# SQLAlchemy                         1.2.7
# srsly                              0.0.5
# statsmodels                        0.9.0
# sympy                              1.1.1
# tables                             3.4.3
# tabulate                           0.8.3
# tblib                              1.3.2
# tensorboard                        1.10.0
# tensorflow                         1.10.0
# tensorflow-estimator               1.13.0
# termcolor                          1.1.0
# terminado                          0.8.1
# terminaltables                     3.1.0
# testpath                           0.3.1
# tflearn                            0.3.2
# thinc                              7.0.4
# toolz                              0.9.0
# tornado                            5.0.2
# tqdm                               4.32.1
# traitlets                          4.3.2
# twilio                             6.27.1
# Twisted                            19.2.0
# typed-ast                          1.4.0
# typing                             3.6.4
# tzlocal                            1.5.1
# unicodecsv                         0.14.1
# urllib3                            1.24.3
# wasabi                             0.2.2
# wcwidth                            0.1.7
# webencodings                       0.5.1
# websocket-client                   0.54.0
# Werkzeug                           0.14.1
# wheel                              0.31.1
# widgetsnbextension                 3.2.1
# win-inet-pton                      1.0.1
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.11.2
# xlrd                               1.1.0
# XlsxWriter                         1.0.4
# xlwings                            0.11.8
# xlwt                               1.3.0
# zict                               0.1.3
# zope.interface                     4.6.0
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ### Explore

# %%
1. How to make padding to mean length of review
2. Different way of converting text into integers
