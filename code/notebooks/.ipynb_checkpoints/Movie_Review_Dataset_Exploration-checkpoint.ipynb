# %%
import os
from nltk.corpus import stopwords
import string
import re
from collections import Counter
from keras.preprocessing.text import Tokenizer

# %%
def load_doc(filename):
    
    file = open(filename, "r")
    
    text = file.read()
    
    file.close()
    return text

# %%
for filename in os.listdir('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/'):
    #print(filename)
    
    if not filename.endswith('.txt'):
        next
    
    doc = load_doc('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/'+filename)
    
    print('Loaded %s' %filename)
# Out:
# Loaded cv000_29416.txt
# Loaded cv001_19502.txt
# Loaded cv002_17424.txt
# Loaded cv003_12683.txt
# Loaded cv004_12641.txt
# Loaded cv005_29357.txt
# Loaded cv006_17022.txt
# Loaded cv007_4992.txt
# Loaded cv008_29326.txt
# Loaded cv009_29417.txt
# Loaded cv010_29063.txt
# Loaded cv011_13044.txt
# Loaded cv012_29411.txt
# Loaded cv013_10494.txt
# Loaded cv014_15600.txt
# Loaded cv015_29356.txt
# Loaded cv016_4348.txt
# Loaded cv017_23487.txt
# Loaded cv018_21672.txt
# Loaded cv019_16117.txt
# Loaded cv020_9234.txt
# Loaded cv021_17313.txt
# Loaded cv022_14227.txt
# Loaded cv023_13847.txt
# Loaded cv024_7033.txt
# Loaded cv025_29825.txt
# Loaded cv026_29229.txt
# Loaded cv027_26270.txt
# Loaded cv028_26964.txt
# Loaded cv029_19943.txt
# Loaded cv030_22893.txt
# Loaded cv031_19540.txt
# Loaded cv032_23718.txt
# Loaded cv033_25680.txt
# Loaded cv034_29446.txt
# Loaded cv035_3343.txt
# Loaded cv036_18385.txt
# Loaded cv037_19798.txt
# Loaded cv038_9781.txt
# Loaded cv039_5963.txt
# ...

# %%
text = load_doc('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/cv000_29416.txt')



#print(tokens)
def clean_doc(text):
    
    tokens = text.split()
    
    re_punc = re.compile('[%s]' %re.escape(string.punctuation))

    tokens = [re_punc.sub('', w) for w in tokens]

    tokens = [word for word in tokens if word.isalpha()]


    print("\n\n -----------After non numeric removal ---------------------")
    print(tokens)

    stop_words = set(stopwords.words('english'))

    tokens = [w for w in tokens if not w in stop_words]


    print("\n\n -----------After Stopwords removal ---------------------")
    print(tokens)


    print("\n\n -----------After short length words removal ---------------------")
    tokens = [word for word in tokens if len(word) > 1]
    print(tokens)
    
    return tokens

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Documents\\GitHub\\NLP-Code-Samples-Book-JasonBrownley\\code\\notebooks'

# %%
def add_doc_to_vocab(filename, vocab):
    # load doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # update counts
    vocab.update(tokens)

# %%
def process_docs(directory, vocab):
    
    for filename in os.listdir(directory):
        
        if not filename.endswith('.txt'):
            next

        #doc = load_doc('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/'+filename)

        path = directory + filename
        print('Loaded %s' %filename)

        add_doc_to_vocab = (path, vocab) 
        
    return vocab

# %%
from collections import Counter
vocab = Counter()

vocab = process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/', vocab)
# Out:
# Loaded cv000_29416.txt
# Loaded cv001_19502.txt
# Loaded cv002_17424.txt
# Loaded cv003_12683.txt
# Loaded cv004_12641.txt
# Loaded cv005_29357.txt
# Loaded cv006_17022.txt
# Loaded cv007_4992.txt
# Loaded cv008_29326.txt
# Loaded cv009_29417.txt
# Loaded cv010_29063.txt
# Loaded cv011_13044.txt
# Loaded cv012_29411.txt
# Loaded cv013_10494.txt
# Loaded cv014_15600.txt
# Loaded cv015_29356.txt
# Loaded cv016_4348.txt
# Loaded cv017_23487.txt
# Loaded cv018_21672.txt
# Loaded cv019_16117.txt
# Loaded cv020_9234.txt
# Loaded cv021_17313.txt
# Loaded cv022_14227.txt
# Loaded cv023_13847.txt
# Loaded cv024_7033.txt
# Loaded cv025_29825.txt
# Loaded cv026_29229.txt
# Loaded cv027_26270.txt
# Loaded cv028_26964.txt
# Loaded cv029_19943.txt
# Loaded cv030_22893.txt
# Loaded cv031_19540.txt
# Loaded cv032_23718.txt
# Loaded cv033_25680.txt
# Loaded cv034_29446.txt
# Loaded cv035_3343.txt
# Loaded cv036_18385.txt
# Loaded cv037_19798.txt
# Loaded cv038_9781.txt
# Loaded cv039_5963.txt
# ...

# %%
print(len(vocab))
# Out:
# 0

# %%
process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/pos/', vocab)
# Out:
# Loaded cv000_29590.txt
# Loaded cv001_18431.txt
# Loaded cv002_15918.txt
# Loaded cv003_11664.txt
# Loaded cv004_11636.txt
# Loaded cv005_29443.txt
# Loaded cv006_15448.txt
# Loaded cv007_4968.txt
# Loaded cv008_29435.txt
# Loaded cv009_29592.txt
# Loaded cv010_29198.txt
# Loaded cv011_12166.txt
# Loaded cv012_29576.txt
# Loaded cv013_10159.txt
# Loaded cv014_13924.txt
# Loaded cv015_29439.txt
# Loaded cv016_4659.txt
# Loaded cv017_22464.txt
# Loaded cv018_20137.txt
# Loaded cv019_14482.txt
# Loaded cv020_8825.txt
# Loaded cv021_15838.txt
# Loaded cv022_12864.txt
# Loaded cv023_12672.txt
# Loaded cv024_6778.txt
# Loaded cv025_3108.txt
# Loaded cv026_29325.txt
# Loaded cv027_25219.txt
# Loaded cv028_26746.txt
# Loaded cv029_18643.txt
# Loaded cv030_21593.txt
# Loaded cv031_18452.txt
# Loaded cv032_22550.txt
# Loaded cv033_24444.txt
# Loaded cv034_29647.txt
# Loaded cv035_3954.txt
# Loaded cv036_16831.txt
# Loaded cv037_18510.txt
# Loaded cv038_9749.txt
# Loaded cv039_6170.txt
# ...

# %%
print(vocab.most_common(50))
# Out:
# []

# %% [markdown]
# ### Creating vocaboulary

# %%
def load_doc(filename):
    
    file = open(filename, "r")
    
    text = file.read()
    
    file.close()
    return text

def clean_doc(text):
    
    tokens = text.split()
    
    re_punc = re.compile('[%s]' %re.escape(string.punctuation))

    tokens = [re_punc.sub('', w) for w in tokens]

    tokens = [word for word in tokens if word.isalpha()]


#     print("\n\n -----------After non numeric removal ---------------------")
#     print(tokens)

    stop_words = set(stopwords.words('english'))

    tokens = [w for w in tokens if not w in stop_words]


#     print("\n\n -----------After Stopwords removal ---------------------")
#     print(tokens)


    ##print("\n\n -----------After short length words removal ---------------------")
    tokens = [word for word in tokens if len(word) > 1]
    ##print(tokens)
    
    return tokens



def add_doc_to_vocab(filename, vocab):
    # load doc
    ##print('execution')
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # update counts
    vocab.update(tokens)
    

def save_list(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()
    
    
    
def process_docs(directory, vocab):
    
    lines = list()
    
    for filename in os.listdir(directory):
        
        if not filename.endswith('.txt'):
            next

        #doc = load_doc('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/'+filename)

        path = directory + filename
        print('Loaded %s' %filename)

        add_doc_to_vocab(path, vocab)




vocab = Counter()
process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/', vocab)
process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/pos/', vocab)
print(len(vocab))

min_occurence = 5
tokens = [k for k,c in vocab.items() if c>=min_occurence]
print(len(tokens))

save_list(tokens, 'C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/output/vocab.txt')
# Out:
# Loaded cv000_29416.txt
# Loaded cv001_19502.txt
# Loaded cv002_17424.txt
# Loaded cv003_12683.txt
# Loaded cv004_12641.txt
# Loaded cv005_29357.txt
# Loaded cv006_17022.txt
# Loaded cv007_4992.txt
# Loaded cv008_29326.txt
# Loaded cv009_29417.txt
# Loaded cv010_29063.txt
# Loaded cv011_13044.txt
# Loaded cv012_29411.txt
# Loaded cv013_10494.txt
# Loaded cv014_15600.txt
# Loaded cv015_29356.txt
# Loaded cv016_4348.txt
# Loaded cv017_23487.txt
# Loaded cv018_21672.txt
# Loaded cv019_16117.txt
# Loaded cv020_9234.txt
# Loaded cv021_17313.txt
# Loaded cv022_14227.txt
# Loaded cv023_13847.txt
# Loaded cv024_7033.txt
# Loaded cv025_29825.txt
# Loaded cv026_29229.txt
# Loaded cv027_26270.txt
# Loaded cv028_26964.txt
# Loaded cv029_19943.txt
# Loaded cv030_22893.txt
# Loaded cv031_19540.txt
# Loaded cv032_23718.txt
# Loaded cv033_25680.txt
# Loaded cv034_29446.txt
# Loaded cv035_3343.txt
# Loaded cv036_18385.txt
# Loaded cv037_19798.txt
# Loaded cv038_9781.txt
# Loaded cv039_5963.txt
# ...

# %% [markdown]
# ### Processing negative.txt and pos.txt based on vocab created

# %%
def load_doc(filename):
    
    file = open(filename, "r")
    
    text = file.read()
    
    file.close()
    return text

def clean_doc(text):
    
    tokens = text.split()
    
    re_punc = re.compile('[%s]' %re.escape(string.punctuation))

    tokens = [re_punc.sub('', w) for w in tokens]

    tokens = [word for word in tokens if word.isalpha()]


#     print("\n\n -----------After non numeric removal ---------------------")
#     print(tokens)

    stop_words = set(stopwords.words('english'))

    tokens = [w for w in tokens if not w in stop_words]


#     print("\n\n -----------After Stopwords removal ---------------------")
#     print(tokens)


    ##print("\n\n -----------After short length words removal ---------------------")
    tokens = [word for word in tokens if len(word) > 1]
    ##print(tokens)
    
    return tokens
    

def save_list(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()
    
    
def doc_to_line(filename, vocab):
    doc = load_doc(filename)
    
    tokens = clean_doc(doc)
    
    tokens = [w for w in tokens if w in vocab]

    return ' '.join(tokens)
    
    
def process_docs(directory, vocab):
    
    lines = list()
    
    for filename in os.listdir(directory):
        
        if not filename.endswith('.txt'):
            next

        #doc = load_doc('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/'+filename)

        path = directory + filename
        print('Loaded %s' %filename)

        line = doc_to_line(path, vocab)
        
        lines.append(line)
        
    return lines


vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# prepare negative reviews
negative_lines = process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/', vocab)
save_list(negative_lines, 'negative.txt')
# prepare positive reviews
positive_lines = process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/pos/', vocab)
save_list(positive_lines, 'positive.txt')
# Out:
# Loaded cv000_29416.txt
# Loaded cv001_19502.txt
# Loaded cv002_17424.txt
# Loaded cv003_12683.txt
# Loaded cv004_12641.txt
# Loaded cv005_29357.txt
# Loaded cv006_17022.txt
# Loaded cv007_4992.txt
# Loaded cv008_29326.txt
# Loaded cv009_29417.txt
# Loaded cv010_29063.txt
# Loaded cv011_13044.txt
# Loaded cv012_29411.txt
# Loaded cv013_10494.txt
# Loaded cv014_15600.txt
# Loaded cv015_29356.txt
# Loaded cv016_4348.txt
# Loaded cv017_23487.txt
# Loaded cv018_21672.txt
# Loaded cv019_16117.txt
# Loaded cv020_9234.txt
# Loaded cv021_17313.txt
# Loaded cv022_14227.txt
# Loaded cv023_13847.txt
# Loaded cv024_7033.txt
# Loaded cv025_29825.txt
# Loaded cv026_29229.txt
# Loaded cv027_26270.txt
# Loaded cv028_26964.txt
# Loaded cv029_19943.txt
# Loaded cv030_22893.txt
# Loaded cv031_19540.txt
# Loaded cv032_23718.txt
# Loaded cv033_25680.txt
# Loaded cv034_29446.txt
# Loaded cv035_3343.txt
# Loaded cv036_18385.txt
# Loaded cv037_19798.txt
# Loaded cv038_9781.txt
# Loaded cv039_5963.txt
# ...

# %%
def load_doc(filename):
    
    file = open(filename, "r")
    
    text = file.read()
    
    file.close()
    return text

def clean_doc(text):
    
    tokens = text.split()
    
    re_punc = re.compile('[%s]' %re.escape(string.punctuation))

    tokens = [re_punc.sub('', w) for w in tokens]

    tokens = [word for word in tokens if word.isalpha()]


#     print("\n\n -----------After non numeric removal ---------------------")
#     print(tokens)

    stop_words = set(stopwords.words('english'))

    tokens = [w for w in tokens if not w in stop_words]


#     print("\n\n -----------After Stopwords removal ---------------------")
#     print(tokens)


    ##print("\n\n -----------After short length words removal ---------------------")
    tokens = [word for word in tokens if len(word) > 1]
    ##print(tokens)
    
    return tokens
    

    
def doc_to_line(filename, vocab):
    doc = load_doc(filename)
    
    tokens = clean_doc(doc)
    
    tokens = [w for w in tokens if w in vocab]

    return ' '.join(tokens)
    
    
def process_docs(directory, vocab):
    
    lines = list()
    
    for filename in os.listdir(directory):
        
        if not filename.endswith('.txt'):
            next

        #doc = load_doc('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/'+filename)

        path = directory + filename
       # print('Loaded %s' %filename)

        line = doc_to_line(path, vocab)
        
        lines.append(line)
        
    return lines

def load_clean_dataset(vocab):
    neg = process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/', vocab)
    pos = process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/pos/', vocab)
    
    docs = neg + pos
    
    labels = [0 for _ in range(len(neg))] + [1 for _ in range(len(pos))]
    
    return docs, labels


vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)

docs, labels = load_clean_dataset(vocab)
print(len(docs), len(labels))
# Out:
# 2000 2000

# %%
def load_doc(filename):
    
    file = open(filename, "r")
    
    text = file.read()
    
    file.close()
    return text

def clean_doc(text):
    
    tokens = text.split()
    
    re_punc = re.compile('[%s]' %re.escape(string.punctuation))

    tokens = [re_punc.sub('', w) for w in tokens]

    tokens = [word for word in tokens if word.isalpha()]


#     print("\n\n -----------After non numeric removal ---------------------")
#     print(tokens)

    stop_words = set(stopwords.words('english'))

    tokens = [w for w in tokens if not w in stop_words]


#     print("\n\n -----------After Stopwords removal ---------------------")
#     print(tokens)


    ##print("\n\n -----------After short length words removal ---------------------")
    tokens = [word for word in tokens if len(word) > 1]
    ##print(tokens)
    
    return tokens
    

    
def doc_to_line(filename, vocab):
    doc = load_doc(filename)
    
    tokens = clean_doc(doc)
    
    tokens = [w for w in tokens if w in vocab]

    return ' '.join(tokens)
    
    
def process_docs(directory, vocab, istrain):
    
    lines = list()
    
    for filename in os.listdir(directory):
        
        if istrain and  filename.startswith('cv9'):
            continue
            
        if not istrain and not filename.startswith('cv9'):
            continue

        #doc = load_doc('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/neg/'+filename)

        path = directory + filename
       # print('Loaded %s' %filename)

        line = doc_to_line(path, vocab)
        
        lines.append(line)
        
    return lines

def load_clean_dataset(vocab, is_train):
    neg = process_docs('../../data/input/txt_sentoken/neg/', vocab, is_train)
    pos = process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/pos/', vocab, is_train)
    
    docs = neg + pos
    
    labels = [0 for _ in range(len(neg))] + [1 for _ in range(len(pos))]
    
    return docs, labels


def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)

train_docs, ytrain = load_clean_dataset(vocab, True)
test_docs, ytest = load_clean_dataset(vocab, False)

tokenizer = create_tokenizer(train_docs)

Xtrain = tokenizer.texts_to_matrix(train_docs, mode='freq')
Xtest = tokenizer.texts_to_matrix(test_docs, mode= 'freq')



print(Xtrain.shape, Xtest.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-c72f58bc97d6> in <module>()
#      93 vocab = set(vocab)
#      94
# ---> 95 train_docs, ytrain = load_clean_dataset(vocab, True)
#      96 test_docs, ytest = load_clean_dataset(vocab, False)
#      97
#
# <ipython-input-6-c72f58bc97d6> in load_clean_dataset(vocab, is_train)
#      73
#      74 def load_clean_dataset(vocab, is_train):
# ---> 75     neg = process_docs('.../data/input/txt_sentoken/neg/', vocab, is_train)
#      76     pos = process_docs('C:/Users/Admin/Documents/GitHub/NLP-Code-Samples-Book-JasonBrownley/data/input/txt_sentoken/pos/', vocab, is_train)
#      77
#
# <ipython-input-6-c72f58bc97d6> in process_docs(directory, vocab, istrain)
#      53     lines = list()
#      54
# ---> 55     for filename in os.listdir(directory):
#      56
#      57         if istrain and  filename.startswith('cv9'):
# ...
